# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy
import random

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 757

# %%
from config import weather_api_key

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + cities[i]
    

for i, city in enumerate(cities):

    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Retrieve lat and long, max temp, % humidity, % cloudness, wind speed, and weather description
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 16 | khasan
# Processing Record 3 of Set 16 | dzhebariki-khaya
# Processing Record 4 of Set 16 | hilo
# Processing Record 5 of Set 16 | bluff
# Processing Record 6 of Set 16 | zhigansk
# Processing Record 7 of Set 16 | urozhaynoye
# Processing Record 8 of Set 16 | rawson
# Processing Record 9 of Set 16 | port-gentil
# Processing Record 10 of Set 16 | albany
# Processing Record 11 of Set 16 | ulaangom
# Processing Record 12 of Set 16 | bengkulu
# Processing Record 13 of Set 16 | saint george
# Processing Record 14 of Set 16 | ushuaia
# Processing Record 15 of Set 16 | punta arenas
# Processing Record 16 of Set 16 | ribeira grande
# Processing Record 17 of Set 16 | saint-pierre
# Processing Record 18 of Set 16 | mataura
# Processing Record 19 of Set 16 | morondava
# Processing Record 20 of Set 16 | vaini
# Processing Record 21 of Set 16 | saskylakh
# Processing Record 22 of Set 16 | rikitea
# Processing Record 23 of Set 16 | eregli
# Processing Record 24 of Set 16 | sisimiut
# Processing Record 25 of Set 16 | constantine
# Processing Record 26 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 16 | udachnyy
# Processing Record 28 of Set 16 | san cristobal
# Processing Record 29 of Set 16 | galesong
# Processing Record 30 of Set 16 | qaanaaq
# Processing Record 31 of Set 16 | hobart
# Processing Record 32 of Set 16 | busselton
# Processing Record 33 of Set 16 | nortelandia
# Processing Record 34 of Set 16 | port hedland
# Processing Record 35 of Set 16 | baracoa
# Processing Record 36 of Set 16 | atuona
# Processing Record 37 of Set 16 | macamic
# Processing Record 38 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 16 | east london
# Processing Record 40 of Set 16 | iisalmi
# Processing Record 41 of Set 16 | sinnamary
# Processing Record 42 of Set 16 | yulara
# Processing Record 43 of Set 16 | hofn
# Processing Record 44 of Set 16 | frontignan
# Processing Record 45 of Set 16 | tasiilaq
# Processing Record 46 of Set 16 | sao joao da barra
# Processing Record 47 of Set 16 | egvekinot
# Processing Record 48 of Set 16 | los llanos de aridane
# Processing Record 49 of Set 16 | kodinsk
# Processing Record 50 of Set 16 | thompson
# Processing Record 1 of Set 17 | kayerkan
# Processing Record 2 of Set 17 | berlevag
# Processing Record 3 of Set 17 | kloulklubed
# Processing Record 4 of Set 17 | ust-kuyga
# Processing Record 5 of Set 17 | aswan
# Processing Record 6 of Set 17 | maarianhamina
# Processing Record 7 of Set 17 | provideniya
# Processing Record 8 of Set 17 | vredendal
# Processing Record 9 of Set 17 | tuktoyaktuk
# Processing Record 10 of Set 17 | port alfred
# Processing Record 11 of Set 17 | nikolskoye
# Processing Record 12 of Set 17 | butaritari
# Processing Record 13 of Set 17 | hermanus
# Processing Record 14 of Set 17 | ola
# Processing Record 15 of Set 17 | tobermory
# Processing Record 16 of Set 17 | carnarvon
# Processing Record 17 of Set 17 | mar del plata
# Processing Record 18 of Set 17 | vestmannaeyjar
# Processing Record 19 of Set 17 | cayenne
# Processing Record 20 of Set 17 | broome
# Processing Record 21 of Set 17 | inirida
# Processing Record 22 of Set 17 | santa fe
# Processing Record 23 of Set 17 | dunedin
# Processing Record 24 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 17 | meulaboh
# Processing Record 26 of Set 17 | samarai
# Processing Record 27 of Set 17 | puerto quijarro
# Processing Record 28 of Set 17 | ust-ilimsk
# Processing Record 29 of Set 17 | margate
# Processing Record 30 of Set 17 | bambous virieux
# Processing Record 31 of Set 17 | port lincoln
# Processing Record 32 of Set 17 | kutum
# Processing Record 33 of Set 17 | barrow
# Processing Record 34 of Set 17 | dedougou
# Processing Record 35 of Set 17 | marsh harbour
# Processing Record 36 of Set 17 | veraval
# Processing Record 37 of Set 17 | yellowknife
# Processing Record 38 of Set 17 | khatanga
# Processing Record 39 of Set 17 | leningradskiy
# Processing Record 40 of Set 17 | nemuro
# Processing Record 41 of Set 17 | santa lucia
# Processing Record 42 of Set 17 | cape town
# Processing Record 43 of Set 17 | necochea
# Processing Record 44 of Set 17 | baghdad
# Processing Record 45 of Set 17 | dharchula
# Processing Record 46 of Set 17 | bainbridge
# Processing Record 47 of Set 17 | saint-philippe
# Processing Record 48 of Set 17 | pueblo nuevo
# Processing Record 49 of Set 17 | new norfolk
# Processing Record 50 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 18 | chaiyaphum
# Processing Record 2 of Set 18 | kieta
# Processing Record 3 of Set 18 | kapaa
# Processing Record 4 of Set 18 | tura
# Processing Record 5 of Set 18 | hamilton
# Processing Record 6 of Set 18 | airai
# Processing Record 7 of Set 18 | santa cruz do sul
# Processing Record 8 of Set 18 | tezu
# Processing Record 9 of Set 18 | jacareacanga
# Processing Record 10 of Set 18 | umm lajj
# Processing Record 11 of Set 18 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 18 | longyearbyen
# Processing Record 13 of Set 18 | salalah
# Processing Record 14 of Set 18 | georgetown
# Processing Record 15 of Set 18 | taoudenni
# Processing Record 16 of Set 18 | chalus
# Processing Record 17 of Set 18 | aksarka
# Processing Record 18 of Set 18 | wagar
# Processing Record 19 of Set 18 | koboldo
# City not found. Skipping...
# Processing Record 20 of Set 18 | severo-kurilsk
# Processing Record 21 of Set 18 | castro
# Processing Record 22 of Set 18 | tabas
# Processing Record 23 of Set 18 | jamestown
# Processing Record 24 of Set 18 | puerto ayora
# Processing Record 25 of Set 18 | dikson
# Processing Record 26 of Set 18 | cabo san lucas
# Processing Record 27 of Set 18 | avarua
# Processing Record 28 of Set 18 | lagoa
# Processing Record 29 of Set 18 | pishin
# Processing Record 30 of Set 18 | upington
# Processing Record 31 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 18 | muncar
# Processing Record 33 of Set 18 | gold coast
# Processing Record 34 of Set 18 | mandiana
# Processing Record 35 of Set 18 | benguela
# Processing Record 36 of Set 18 | akhtanizovskaya
# Processing Record 37 of Set 18 | jieshi
# Processing Record 38 of Set 18 | paamiut
# Processing Record 39 of Set 18 | arraial do cabo
# Processing Record 40 of Set 18 | upernavik
# Processing Record 41 of Set 18 | mosquera
# Processing Record 42 of Set 18 | bredasdorp
# Processing Record 43 of Set 18 | praia
# Processing Record 44 of Set 18 | yumen
# Processing Record 45 of Set 18 | juneau
# Processing Record 46 of Set 18 | xapuri
# Processing Record 47 of Set 18 | suoyarvi
# Processing Record 48 of Set 18 | kemijarvi
# Processing Record 49 of Set 18 | henties bay
# Processing Record 50 of Set 18 | jaipur hat
# City not found. Skipping...
# Processing Record 1 of Set 19 | te anau
# Processing Record 2 of Set 19 | coquimbo
# Processing Record 3 of Set 19 | porto nacional
# Processing Record 4 of Set 19 | hithadhoo
# Processing Record 5 of Set 19 | kharp
# Processing Record 6 of Set 19 | raudeberg
# Processing Record 7 of Set 19 | cheyur
# City not found. Skipping...
# Processing Record 8 of Set 19 | awash
# Processing Record 9 of Set 19 | bengkalis
# City not found. Skipping...
# Processing Record 10 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 19 | fairbanks
# Processing Record 12 of Set 19 | tiksi
# Processing Record 13 of Set 19 | lapua
# Processing Record 14 of Set 19 | balagansk
# Processing Record 15 of Set 19 | najran
# Processing Record 16 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 19 | nanortalik
# Processing Record 18 of Set 19 | arman
# Processing Record 19 of Set 19 | nerchinskiy zavod
# Processing Record 20 of Set 19 | srandakan
# Processing Record 21 of Set 19 | dhidhdhoo
# Processing Record 22 of Set 19 | saint anthony
# Processing Record 23 of Set 19 | baruun-urt
# Processing Record 24 of Set 19 | cidreira
# Processing Record 25 of Set 19 | alofi
# Processing Record 26 of Set 19 | iqaluit
# Processing Record 27 of Set 19 | waingapu
# Processing Record 28 of Set 19 | pedasi
# Processing Record 29 of Set 19 | ostrovnoy
# Processing Record 30 of Set 19 | odoyev
# Processing Record 31 of Set 19 | sitka
# Processing Record 32 of Set 19 | socorro
# Processing Record 33 of Set 19 | ngunguru
# Processing Record 34 of Set 19 | geraldton
# Processing Record 35 of Set 19 | sobolevo
# Processing Record 36 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 19 | saint-joseph
# Processing Record 38 of Set 19 | flinders
# Processing Record 39 of Set 19 | victoria
# Processing Record 40 of Set 19 | dingle
# Processing Record 41 of Set 19 | santa marta
# Processing Record 42 of Set 19 | roma
# Processing Record 43 of Set 19 | nhulunbuy
# Processing Record 44 of Set 19 | kushiro
# Processing Record 45 of Set 19 | eenhana
# Processing Record 46 of Set 19 | asmar
# Processing Record 47 of Set 19 | ilulissat
# Processing Record 48 of Set 19 | camacha
# Processing Record 49 of Set 19 | porto novo
# Processing Record 50 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 20 | coihaique
# Processing Record 2 of Set 20 | sur
# Processing Record 3 of Set 20 | lorengau
# Processing Record 4 of Set 20 | cairns
# Processing Record 5 of Set 20 | chokurdakh
# Processing Record 6 of Set 20 | zandak
# Processing Record 7 of Set 20 | narsaq
# Processing Record 8 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 20 | san quintin
# Processing Record 10 of Set 20 | churapcha
# Processing Record 11 of Set 20 | mecca
# Processing Record 12 of Set 20 | blairmore
# Processing Record 13 of Set 20 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 20 | mayumba
# Processing Record 15 of Set 20 | madang
# Processing Record 16 of Set 20 | marawi
# Processing Record 17 of Set 20 | ponta do sol
# Processing Record 18 of Set 20 | kodiak
# Processing Record 19 of Set 20 | warren
# Processing Record 20 of Set 20 | kaitangata
# Processing Record 21 of Set 20 | tilichiki
# Processing Record 22 of Set 20 | souillac
# Processing Record 23 of Set 20 | cantagallo
# Processing Record 24 of Set 20 | san miguel
# Processing Record 25 of Set 20 | yeppoon
# Processing Record 26 of Set 20 | mayo
# Processing Record 27 of Set 20 | saldanha
# Processing Record 28 of Set 20 | tukrah
# Processing Record 29 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 20 | vila franca do campo
# Processing Record 31 of Set 20 | sangar
# Processing Record 32 of Set 20 | shambu
# Processing Record 33 of Set 20 | pontarlier
# Processing Record 34 of Set 20 | nsanje
# Processing Record 35 of Set 20 | guerrero negro
# Processing Record 36 of Set 20 | trairi
# Processing Record 37 of Set 20 | contamana
# Processing Record 38 of Set 20 | novobessergenevka
# Processing Record 39 of Set 20 | quatre cocos
# Processing Record 40 of Set 20 | oksfjord
# Processing Record 41 of Set 20 | nampa
# Processing Record 42 of Set 20 | guanica
# Processing Record 43 of Set 20 | jelgava
# Processing Record 44 of Set 20 | fernley
# Processing Record 45 of Set 20 | broken hill
# Processing Record 46 of Set 20 | comodoro rivadavia
# Processing Record 47 of Set 20 | chuy
# Processing Record 48 of Set 20 | campos belos
# Processing Record 49 of Set 20 | hlobyne
# Processing Record 50 of Set 20 | westport
# Processing Record 1 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 21 | ancud
# Processing Record 3 of Set 21 | acapulco
# Processing Record 4 of Set 21 | hasaki
# Processing Record 5 of Set 21 | lompoc
# Processing Record 6 of Set 21 | harwich
# Processing Record 7 of Set 21 | chama
# Processing Record 8 of Set 21 | gat
# Processing Record 9 of Set 21 | faanui
# Processing Record 10 of Set 21 | camana
# Processing Record 11 of Set 21 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 21 | kenai
# Processing Record 13 of Set 21 | portland
# Processing Record 14 of Set 21 | fremont
# Processing Record 15 of Set 21 | bryan
# Processing Record 16 of Set 21 | zhangjiakou
# Processing Record 17 of Set 21 | alyangula
# Processing Record 18 of Set 21 | san patricio
# Processing Record 19 of Set 21 | beira
# Processing Record 20 of Set 21 | mata
# Processing Record 21 of Set 21 | port augusta
# Processing Record 22 of Set 21 | komsomolskiy
# Processing Record 23 of Set 21 | christchurch
# Processing Record 24 of Set 21 | valleyview
# Processing Record 25 of Set 21 | port elizabeth
# Processing Record 26 of Set 21 | price
# Processing Record 27 of Set 21 | carbondale
# Processing Record 28 of Set 21 | general roca
# Processing Record 29 of Set 21 | kuytun
# Processing Record 30 of Set 21 | haines junction
# Processing Record 31 of Set 21 | nagato
# Processing Record 32 of Set 21 | kendari
# Processing Record 33 of Set 21 | kahului
# Processing Record 34 of Set 21 | yar-sale
# Processing Record 35 of Set 21 | bud
# Processing Record 36 of Set 21 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 21 | khrustalnyy
# City not found. Skipping...
# Processing Record 38 of Set 21 | maniitsoq
# Processing Record 39 of Set 21 | sivas
# Processing Record 40 of Set 21 | igrim
# Processing Record 41 of Set 21 | bonavista
# Processing Record 42 of Set 21 | witu
# Processing Record 43 of Set 21 | kaduqli
# Processing Record 44 of Set 21 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 21 | rehoboth
# Processing Record 46 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 21 | yashkul
# Processing Record 48 of Set 21 | asau
# Processing Record 49 of Set 21 | inuvik
# Processing Record 50 of Set 21 | sungairaya
# Processing Record 1 of Set 22 | krasnoselkup
# Processing Record 2 of Set 22 | placido de castro
# Processing Record 3 of Set 22 | taizhou
# Processing Record 4 of Set 22 | esperance
# Processing Record 5 of Set 22 | vanimo
# Processing Record 6 of Set 22 | kyabe
# Processing Record 7 of Set 22 | calama
# Processing Record 8 of Set 22 | alice springs
# Processing Record 9 of Set 22 | aklavik
# Processing Record 10 of Set 22 | vila do maio
# Processing Record 11 of Set 22 | lebu
# Processing Record 12 of Set 22 | kaniama
# Processing Record 13 of Set 22 | ushtobe
# Processing Record 14 of Set 22 | felidhoo
# City not found. Skipping...
# Processing Record 15 of Set 22 | torbay
# Processing Record 16 of Set 22 | mandalgovi
# Processing Record 17 of Set 22 | tenosique
# Processing Record 18 of Set 22 | erenhot
# Processing Record 19 of Set 22 | liminangcong
# City not found. Skipping...
# Processing Record 20 of Set 22 | fortuna
# Processing Record 21 of Set 22 | muros
# Processing Record 22 of Set 22 | marsa matruh
# Processing Record 23 of Set 22 | mukhtolovo
# Processing Record 24 of Set 22 | pedernales
# Processing Record 25 of Set 22 | takoradi
# Processing Record 26 of Set 22 | touros
# Processing Record 27 of Set 22 | mahebourg
# Processing Record 28 of Set 22 | bridgetown
# Processing Record 29 of Set 22 | waipawa
# Processing Record 30 of Set 22 | singapore
# Processing Record 31 of Set 22 | seinajoki
# Processing Record 32 of Set 22 | manokwari
# Processing Record 33 of Set 22 | bac lieu
# Processing Record 34 of Set 22 | clyde river
# Processing Record 35 of Set 22 | uray
# Processing Record 36 of Set 22 | natitingou
# Processing Record 37 of Set 22 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 22 | jaguarari
# Processing Record 39 of Set 22 | dingli
# Processing Record 40 of Set 22 | anadyr
# Processing Record 41 of Set 22 | russell
# Processing Record 42 of Set 22 | privas
# Processing Record 43 of Set 22 | torbat-e jam
# Processing Record 44 of Set 22 | kismayo
# Processing Record 45 of Set 22 | ust-koksa
# Processing Record 46 of Set 22 | cherskiy
# Processing Record 47 of Set 22 | cheltenham
# Processing Record 48 of Set 22 | sibu
# Processing Record 49 of Set 22 | nome
# Processing Record 50 of Set 22 | kaeo
# Processing Record 1 of Set 23 | ishigaki
# Processing Record 2 of Set 23 | pitanga
# Processing Record 3 of Set 23 | lata
# Processing Record 4 of Set 23 | bethel
# Processing Record 5 of Set 23 | buraydah
# Processing Record 6 of Set 23 | kysyl-syr
# Processing Record 7 of Set 23 | cloquet
# Processing Record 8 of Set 23 | beloha
# Processing Record 9 of Set 23 | noumea
# Processing Record 10 of Set 23 | tagudin
# Processing Record 11 of Set 23 | nuevitas
# Processing Record 12 of Set 23 | banda aceh
# Processing Record 13 of Set 23 | nanakuli
# Processing Record 14 of Set 23 | la paz
# Processing Record 15 of Set 23 | letka
# Processing Record 16 of Set 23 | batagay-alyta
# Processing Record 17 of Set 23 | mabaruma
# Processing Record 18 of Set 23 | worland
# Processing Record 19 of Set 23 | lewistown
# Processing Record 20 of Set 23 | bahadurgarh
# Processing Record 21 of Set 23 | carolina
# Processing Record 22 of Set 23 | ahipara
# Processing Record 23 of Set 23 | sherlovaya gora
# Processing Record 24 of Set 23 | lubango
# Processing Record 25 of Set 23 | constitucion
# Processing Record 26 of Set 23 | tshikapa
# Processing Record 27 of Set 23 | kavieng
# Processing Record 28 of Set 23 | plettenberg bay
# Processing Record 29 of Set 23 | cam ranh
# Processing Record 30 of Set 23 | severnyy
# Processing Record 31 of Set 23 | santa maria chiquimula
# Processing Record 32 of Set 23 | bam
# Processing Record 33 of Set 23 | aquiraz
# Processing Record 34 of Set 23 | shediac
# Processing Record 35 of Set 23 | yemelyanovo
# Processing Record 36 of Set 23 | severnoye
# Processing Record 37 of Set 23 | alvorada
# Processing Record 38 of Set 23 | okhotsk
# Processing Record 39 of Set 23 | quang ngai
# Processing Record 40 of Set 23 | warmbad
# Processing Record 41 of Set 23 | goranboy
# Processing Record 42 of Set 23 | luanda
# Processing Record 43 of Set 23 | sorland
# Processing Record 44 of Set 23 | klaksvik
# Processing Record 45 of Set 23 | kankon
# Processing Record 46 of Set 23 | sola
# Processing Record 47 of Set 23 | evensk
# Processing Record 48 of Set 23 | raymond
# Processing Record 49 of Set 23 | labuhan
# Processing Record 50 of Set 23 | mahibadhoo
# Processing Record 1 of Set 24 | pindiga
# Processing Record 2 of Set 24 | padang
# Processing Record 3 of Set 24 | mingguang
# Processing Record 4 of Set 24 | kawana waters
# City not found. Skipping...
# Processing Record 5 of Set 24 | suluq
# Processing Record 6 of Set 24 | arica
# Processing Record 7 of Set 24 | bahir dar
# Processing Record 8 of Set 24 | tarudant
# City not found. Skipping...
# Processing Record 9 of Set 24 | nabire
# Processing Record 10 of Set 24 | kyra
# Processing Record 11 of Set 24 | kavaratti
# Processing Record 12 of Set 24 | vila
# Processing Record 13 of Set 24 | diapaga
# Processing Record 14 of Set 24 | rocha
# Processing Record 15 of Set 24 | sataua
# City not found. Skipping...
# Processing Record 16 of Set 24 | barcelos
# Processing Record 17 of Set 24 | marktoberdorf
# Processing Record 18 of Set 24 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 24 | westerly
# Processing Record 21 of Set 24 | galbshtadt
# Processing Record 22 of Set 24 | marrakesh
# Processing Record 23 of Set 24 | charters towers
# Processing Record 24 of Set 24 | kudahuvadhoo
# Processing Record 25 of Set 24 | honningsvag
# Processing Record 26 of Set 24 | tucurui
# Processing Record 27 of Set 24 | baglan
# Processing Record 28 of Set 24 | chikoy
# City not found. Skipping...
# Processing Record 29 of Set 24 | kralendijk
# Processing Record 30 of Set 24 | mananara
# Processing Record 31 of Set 24 | north bend
# Processing Record 32 of Set 24 | basco
# Processing Record 33 of Set 24 | praya
# Processing Record 34 of Set 24 | caravelas
# Processing Record 35 of Set 24 | rey bouba
# Processing Record 36 of Set 24 | neiafu
# Processing Record 37 of Set 24 | akyab
# Processing Record 38 of Set 24 | russkiy
# Processing Record 39 of Set 24 | gaoua
# Processing Record 40 of Set 24 | zlobin
# Processing Record 41 of Set 24 | mattru
# Processing Record 42 of Set 24 | ha giang
# Processing Record 43 of Set 24 | gimli
# Processing Record 44 of Set 24 | tir pol
# City not found. Skipping...
# Processing Record 45 of Set 24 | silver city
# Processing Record 46 of Set 24 | rengo
# Processing Record 47 of Set 24 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 24 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 24 | hambantota
# Processing Record 50 of Set 24 | cockburn town
# Processing Record 1 of Set 25 | belaya gora
# Processing Record 2 of Set 25 | moron
# Processing Record 3 of Set 25 | codrington
# Processing Record 4 of Set 25 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 25 | kuah
# Processing Record 6 of Set 25 | lambarene
# Processing Record 7 of Set 25 | arrifes
# Processing Record 8 of Set 25 | kisangani
# Processing Record 9 of Set 25 | sheregesh
# Processing Record 10 of Set 25 | santa rosa
# Processing Record 11 of Set 25 | spoleto
# Processing Record 12 of Set 25 | faya
# Processing Record 13 of Set 25 | erzin
# Processing Record 14 of Set 25 | petrivka
# Processing Record 15 of Set 25 | wageningen
# Processing Record 16 of Set 25 | aguimes
# Processing Record 17 of Set 25 | gazojak
# Processing Record 18 of Set 25 | poum
# Processing Record 19 of Set 25 | nuuk
# Processing Record 20 of Set 25 | atar
# Processing Record 21 of Set 25 | santa maria
# Processing Record 22 of Set 25 | nara
# Processing Record 23 of Set 25 | husavik
# Processing Record 24 of Set 25 | rambha
# Processing Record 25 of Set 25 | guiglo
# Processing Record 26 of Set 25 | bria
# Processing Record 27 of Set 25 | san carlos de bariloche
# Processing Record 28 of Set 25 | mayor pablo lagerenza
# Processing Record 29 of Set 25 | yantai
# Processing Record 30 of Set 25 | tuatapere
# Processing Record 31 of Set 25 | sao gabriel da cachoeira
# Processing Record 32 of Set 25 | ewa beach
# Processing Record 33 of Set 25 | linshui
# Processing Record 34 of Set 25 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 25 | namibe
# Processing Record 36 of Set 25 | conde
# Processing Record 37 of Set 25 | ovsyanka
# Processing Record 38 of Set 25 | atasu
# Processing Record 39 of Set 25 | rahimatpur
# Processing Record 40 of Set 25 | ulladulla
# Processing Record 41 of Set 25 | port hardy
# Processing Record 42 of Set 25 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 25 | shadrinsk
# Processing Record 44 of Set 25 | chara
# Processing Record 45 of Set 25 | jutai
# Processing Record 46 of Set 25 | tabou
# Processing Record 47 of Set 25 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 25 | kushima
# Processing Record 49 of Set 25 | wajima
# Processing Record 50 of Set 25 | omboue
# Processing Record 1 of Set 26 | terrak
# Processing Record 2 of Set 26 | mount gambier
# Processing Record 3 of Set 26 | sept-iles
# Processing Record 4 of Set 26 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 5 of Set 26 | muleba
# Processing Record 6 of Set 26 | dhone
# Processing Record 7 of Set 26 | ankazoabo
# Processing Record 8 of Set 26 | isangel
# Processing Record 9 of Set 26 | masallatah
# Processing Record 10 of Set 26 | srednekolymsk
# Processing Record 11 of Set 26 | stokmarknes
# Processing Record 12 of Set 26 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 26 | kasamwa
# Processing Record 14 of Set 26 | polovinnoye
# Processing Record 15 of Set 26 | la rioja
# Processing Record 16 of Set 26 | roald
# Processing Record 17 of Set 26 | kasongo
# Processing Record 18 of Set 26 | chase
# Processing Record 19 of Set 26 | brigantine
# Processing Record 20 of Set 26 | uvinza
# Processing Record 21 of Set 26 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 26 | bathsheba
# Processing Record 23 of Set 26 | baykalovo
# Processing Record 24 of Set 26 | nago
# Processing Record 25 of Set 26 | semey
# Processing Record 26 of Set 26 | namatanai
# Processing Record 27 of Set 26 | plastun
# Processing Record 28 of Set 26 | arsenyev
# Processing Record 29 of Set 26 | smithers
# Processing Record 30 of Set 26 | tiarei
# Processing Record 31 of Set 26 | ust-maya
# Processing Record 32 of Set 26 | bambanglipuro
# Processing Record 33 of Set 26 | goderich
# Processing Record 34 of Set 26 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 26 | tsirguliina
# Processing Record 36 of Set 26 | san felipe
# Processing Record 37 of Set 26 | toshkivka
# Processing Record 38 of Set 26 | impfondo
# Processing Record 39 of Set 26 | kandrian
# Processing Record 40 of Set 26 | xinzhou
# Processing Record 41 of Set 26 | harper
# Processing Record 42 of Set 26 | newport
# Processing Record 43 of Set 26 | batemans bay
# Processing Record 44 of Set 26 | belmonte
# Processing Record 45 of Set 26 | luderitz
# Processing Record 46 of Set 26 | koumac
# Processing Record 47 of Set 26 | pemangkat
# Processing Record 48 of Set 26 | ponta delgada
# Processing Record 49 of Set 26 | ambon
# Processing Record 50 of Set 26 | morant bay
# Processing Record 1 of Set 27 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 27 | zhukovo
# Processing Record 3 of Set 27 | talnakh
# Processing Record 4 of Set 27 | naze
# Processing Record 5 of Set 27 | khandyga
# Processing Record 6 of Set 27 | siocon
# Processing Record 7 of Set 27 | dubti
# Processing Record 8 of Set 27 | norman wells
# Processing Record 9 of Set 27 | mitchell
# Processing Record 10 of Set 27 | tautira
# Processing Record 11 of Set 27 | tromso
# Processing Record 12 of Set 27 | tongren
# Processing Record 13 of Set 27 | leh
# Processing Record 14 of Set 27 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 27 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 27 | milton
# Processing Record 17 of Set 27 | leshukonskoye
# Processing Record 18 of Set 27 | kaka
# Processing Record 19 of Set 27 | finschhafen
# Processing Record 20 of Set 27 | esso
# Processing Record 21 of Set 27 | pevek
# Processing Record 22 of Set 27 | keshan
# City not found. Skipping...
# Processing Record 23 of Set 27 | hell
# Processing Record 24 of Set 27 | west bay
# Processing Record 25 of Set 27 | cap malheureux
# Processing Record 26 of Set 27 | gorom-gorom
# Processing Record 27 of Set 27 | puerto maldonado
# Processing Record 28 of Set 27 | along
# Processing Record 29 of Set 27 | westlock
# Processing Record 30 of Set 27 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 27 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 32 of Set 27 | stonewall
# Processing Record 33 of Set 27 | parambu
# Processing Record 34 of Set 27 | louviers
# Processing Record 35 of Set 27 | hay river
# Processing Record 36 of Set 27 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 37 of Set 27 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 27 | tampere
# Processing Record 39 of Set 27 | tando muhammad khan
# Processing Record 40 of Set 27 | northam
# Processing Record 41 of Set 27 | bolshiye uki
# City not found. Skipping...
# Processing Record 42 of Set 27 | hami
# Processing Record 43 of Set 27 | llanes
# Processing Record 44 of Set 27 | kuching
# Processing Record 45 of Set 27 | kuhdasht
# Processing Record 46 of Set 27 | hwange
# Processing Record 47 of Set 27 | shubarshi
# Processing Record 48 of Set 27 | lander
# Processing Record 49 of Set 27 | alexandria
# Processing Record 50 of Set 27 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 28 | vostok
# Processing Record 2 of Set 28 | sampit
# Processing Record 3 of Set 28 | artyk
# City not found. Skipping...
# Processing Record 4 of Set 28 | klyuchi
# Processing Record 5 of Set 28 | paratinga
# Processing Record 6 of Set 28 | axim
# Processing Record 7 of Set 28 | thessalon
# Processing Record 8 of Set 28 | saint-francois
# Processing Record 9 of Set 28 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 28 | byron bay
# Processing Record 11 of Set 28 | katsuura
# Processing Record 12 of Set 28 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 28 | kalmunai
# Processing Record 14 of Set 28 | gornopravdinsk
# Processing Record 15 of Set 28 | bandarbeyla
# Processing Record 16 of Set 28 | camopi
# Processing Record 17 of Set 28 | hovd
# Processing Record 18 of Set 28 | marzuq
# Processing Record 19 of Set 28 | melfort
# Processing Record 20 of Set 28 | heiligenhafen
# Processing Record 21 of Set 28 | lupiro
# Processing Record 22 of Set 28 | amot
# Processing Record 23 of Set 28 | caxias
# Processing Record 24 of Set 28 | denpasar
# Processing Record 25 of Set 28 | mao
# Processing Record 26 of Set 28 | puerto del rosario
# Processing Record 27 of Set 28 | carutapera
# Processing Record 28 of Set 28 | tomatlan
# Processing Record 29 of Set 28 | skarnes
# Processing Record 30 of Set 28 | ilorin
# Processing Record 31 of Set 28 | wasilla
# Processing Record 32 of Set 28 | pastavy
# Processing Record 33 of Set 28 | iskateley
# Processing Record 34 of Set 28 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 28 | iseyin
# Processing Record 36 of Set 28 | khash
# Processing Record 37 of Set 28 | vardo
# Processing Record 38 of Set 28 | valparaiso
# Processing Record 39 of Set 28 | ayios andreas
# City not found. Skipping...
# Processing Record 40 of Set 28 | korla
# Processing Record 41 of Set 28 | dicabisagan
# Processing Record 42 of Set 28 | nioro
# Processing Record 43 of Set 28 | toowoomba
# Processing Record 44 of Set 28 | vila velha
# Processing Record 45 of Set 28 | laem sing
# Processing Record 46 of Set 28 | itarema
# Processing Record 47 of Set 28 | batagay
# Processing Record 48 of Set 28 | melilla
# Processing Record 49 of Set 28 | college
# Processing Record 50 of Set 28 | glazov
# Processing Record 1 of Set 29 | pringsewu
# Processing Record 2 of Set 29 | pacifica
# Processing Record 3 of Set 29 | kisesa
# Processing Record 4 of Set 29 | opuwo
# Processing Record 5 of Set 29 | chandur
# Processing Record 6 of Set 29 | daryapur
# Processing Record 7 of Set 29 | lavrentiya
# Processing Record 8 of Set 29 | guanambi
# Processing Record 9 of Set 29 | willmar
# Processing Record 10 of Set 29 | shu
# Processing Record 11 of Set 29 | deniliquin
# Processing Record 12 of Set 29 | ahuimanu
# Processing Record 13 of Set 29 | higuey
# City not found. Skipping...
# Processing Record 14 of Set 29 | wanganui
# Processing Record 15 of Set 29 | darlawn
# Processing Record 16 of Set 29 | lipin bor
# Processing Record 17 of Set 29 | grindavik
# Processing Record 18 of Set 29 | achisay
# City not found. Skipping...
# Processing Record 19 of Set 29 | nizhniy tsasuchey
# Processing Record 20 of Set 29 | cantaura
# Processing Record 21 of Set 29 | araguatins
# City not found. Skipping...
# Processing Record 22 of Set 29 | yei
# Processing Record 23 of Set 29 | aripuana
# Processing Record 24 of Set 29 | muridke
# Processing Record 25 of Set 29 | grand gaube
# Processing Record 26 of Set 29 | inverell
# Processing Record 27 of Set 29 | quimper
# Processing Record 28 of Set 29 | cabinda
# Processing Record 29 of Set 29 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 29 | jalu
# Processing Record 31 of Set 29 | manono
# Processing Record 32 of Set 29 | talcahuano
# Processing Record 33 of Set 29 | high rock
# Processing Record 34 of Set 29 | mehamn
# Processing Record 35 of Set 29 | hastings
# Processing Record 36 of Set 29 | rio gallegos
# Processing Record 37 of Set 29 | cordenons
# Processing Record 38 of Set 29 | araouane
# Processing Record 39 of Set 29 | upata
# Processing Record 40 of Set 29 | ponca city
# Processing Record 41 of Set 29 | funadhoo
# Processing Record 42 of Set 29 | severiano melo
# Processing Record 43 of Set 29 | sadowara
# City not found. Skipping...
# Processing Record 44 of Set 29 | barguzin
# Processing Record 45 of Set 29 | gao
# Processing Record 46 of Set 29 | makung
# City not found. Skipping...
# Processing Record 47 of Set 29 | gracac
# Processing Record 48 of Set 29 | sao filipe
# Processing Record 49 of Set 29 | uige
# Processing Record 50 of Set 29 | kingman
# Processing Record 1 of Set 30 | olafsvik
# Processing Record 2 of Set 30 | kayalpattinam
# Processing Record 3 of Set 30 | makakilo city
# Processing Record 4 of Set 30 | la peca
# Processing Record 5 of Set 30 | badamdar
# Processing Record 6 of Set 30 | santana do livramento
# Processing Record 7 of Set 30 | vao
# Processing Record 8 of Set 30 | southbridge
# Processing Record 9 of Set 30 | scarborough
# Processing Record 10 of Set 30 | golcuk
# City not found. Skipping...
# Processing Record 11 of Set 30 | kencong
# Processing Record 12 of Set 30 | pangnirtung
# Processing Record 13 of Set 30 | las palmas
# Processing Record 14 of Set 30 | aksu
# Processing Record 15 of Set 30 | negele
# City not found. Skipping...
# Processing Record 16 of Set 30 | rio blanco
# Processing Record 17 of Set 30 | xihe
# Processing Record 18 of Set 30 | stornoway
# Processing Record 19 of Set 30 | agirish
# Processing Record 20 of Set 30 | medea
# Processing Record 21 of Set 30 | beringovskiy
# Processing Record 22 of Set 30 | bosaso
# Processing Record 23 of Set 30 | strezhevoy
# Processing Record 24 of Set 30 | karatau
# Processing Record 25 of Set 30 | palmer
# Processing Record 26 of Set 30 | alekseyevka
# Processing Record 27 of Set 30 | sao miguel do araguaia
# Processing Record 28 of Set 30 | manta
# Processing Record 29 of Set 30 | kruisfontein
# Processing Record 30 of Set 30 | zhangzhou
# Processing Record 31 of Set 30 | saint-leu
# Processing Record 32 of Set 30 | perth
# Processing Record 33 of Set 30 | loubomo
# Processing Record 34 of Set 30 | cheuskiny
# City not found. Skipping...
# Processing Record 35 of Set 30 | laguna
# Processing Record 36 of Set 30 | abomsa
# Processing Record 37 of Set 30 | harrisonville
# Processing Record 38 of Set 30 | ust-nera
# Processing Record 39 of Set 30 | tapes
# Processing Record 40 of Set 30 | kuryk
# Processing Record 41 of Set 30 | banjar
# Processing Record 42 of Set 30 | avera
# Processing Record 43 of Set 30 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 30 | ca mau
# Processing Record 45 of Set 30 | san francisco
# Processing Record 46 of Set 30 | vestmanna
# Processing Record 47 of Set 30 | havoysund
# Processing Record 48 of Set 30 | zhangye
# Processing Record 49 of Set 30 | pangai
# Processing Record 50 of Set 30 | porto santo
# Processing Record 1 of Set 31 | qui nhon
# Processing Record 2 of Set 31 | mount isa
# Processing Record 3 of Set 31 | boende
# Processing Record 4 of Set 31 | otane
# Processing Record 5 of Set 31 | lagos
# Processing Record 6 of Set 31 | tottori
# Processing Record 7 of Set 31 | shilka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the date
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Append Column Names
city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})

# %%
#Add the data to a new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Khasan      RU  42.4308  130.6434     50.23        96
# 1  Dzhebariki-Khaya      RU  62.2167  135.8000     70.74        51
# 2              Hilo      US  19.7297 -155.0900     89.28        87
# 3             Bluff      NZ -46.6000  168.3333     46.80        66
# 4          Zhigansk      RU  66.7697  123.3711     59.09        56
# 5       Urozhaynoye      RU  44.7883   44.9228     69.67        50
# 6            Rawson      AR -43.3002  -65.1023     50.22        59
# 7       Port-Gentil      GA  -0.7193    8.7815     75.16        94
# 8            Albany      US  42.6001  -73.9662     72.01        42
# 9          Ulaangom      MN  49.9811   92.0667     55.13        45
#
#    Cloudiness  Wind Speed Current Description
# 0         100       19.77     overcast clouds
# 1          19        2.01          few clouds
# 2         100       10.36     overcast clouds
# 3         100       11.97     overcast clouds
# 4          48        9.26    scattered clouds
# 5         100        7.05     overcast clouds
# 6          22        7.14          few clouds
# 7          20        2.30          few clouds
# 8          27       11.99    scattered clouds
# 9          75        3.91       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database.csv")
